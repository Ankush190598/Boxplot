# %%
 pip install statannotations
# Out:
# Requirement already satisfied: statannotations in /Users/ankushyadav/opt/anaconda3/lib/python3.9/site-packages (0.4.4)
# Requirement already satisfied: matplotlib>=2.2.2 in /Users/ankushyadav/opt/anaconda3/lib/python3.9/site-packages (from statannotations) (3.5.1)
# Requirement already satisfied: seaborn>=0.9.0 in /Users/ankushyadav/opt/anaconda3/lib/python3.9/site-packages (from statannotations) (0.11.2)
# Requirement already satisfied: numpy>=1.12.1 in /Users/ankushyadav/opt/anaconda3/lib/python3.9/site-packages (from statannotations) (1.21.5)
# Requirement already satisfied: pandas>=0.23.0 in /Users/ankushyadav/opt/anaconda3/lib/python3.9/site-packages (from statannotations) (1.4.2)
# Requirement already satisfied: scipy>=1.1.0 in /Users/ankushyadav/opt/anaconda3/lib/python3.9/site-packages (from statannotations) (1.7.3)
# Requirement already satisfied: packaging>=20.0 in /Users/ankushyadav/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2.2->statannotations) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/ankushyadav/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2.2->statannotations) (1.4.2)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/ankushyadav/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2.2->statannotations) (4.25.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/ankushyadav/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2.2->statannotations) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in /Users/ankushyadav/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2.2->statannotations) (9.0.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/ankushyadav/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2.2->statannotations) (3.0.4)
# Requirement already satisfied: cycler>=0.10 in /Users/ankushyadav/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2.2->statannotations) (0.11.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/ankushyadav/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.23.0->statannotations) (2022.1)
# Requirement already satisfied: six>=1.5 in /Users/ankushyadav/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=2.2.2->statannotations) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from statannotations.Annotator import Annotator
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
sns.set_style("white")

# %%
#loading data already available from seaborn dataset
df=sns.load_dataset("tips")

#if you want to make fraph using your data
#use this code instead of sns.load_dataset
#df= pd.read_csv("yourfilename.csv")

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.set(rc={"figure.figsize":(8, 8)})
ax= sns.boxplot(data=df, x="day", y="total_bill", order = ["Sun", "Thur", "Fri", "Sat"], showfliers=False, color="gray")
kwargs= {"edgecolor": "0.2", "linewidth":1.0}
ax= sns.swarmplot(data=df, x="day", y="total_bill", order = ["Sun", "Thur", "Fri", "Sat"], **kwargs, color="black")
 

for axis in['bottom','left']:
    ax.spines[axis].set_linewidth(2.5)
    ax.spines[axis].set_color('0.2')
    
#remove spines from right and bottom
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
#adding xlabel and ylabel and increasing their fontsize from default condition
ax.set_xlabel("Day", fontsize=20)
ax.set_ylabel("Total_bill", fontsize=20)

#modifying x-axis and y-axis point
plt.xticks(size=14,rotation=35,rotation_mode='anchor',ha='right',weight='bold',color='0.2')
plt.yticks(size=14,weight='bold',color='0.2')
ax.tick_params(width=2.5,color='0.2')
ax.set_facecolor("white")
plt.grid(False)

#adding significant value in the graph using Mann-Whitney test with multiple comparison correction
annot = Annotator (ax, [("Sun", "Thur"), ("Sun", "Sat"), ("Fri", "Sun")], data=df, x="day", y="total_bill", order = ["Sun", "Thur", "Fri", "Sat"]) 
annot.configure(test="Mann-Whitney", text_format='star', loc='outside', verbose=2)
annot.apply_test()
ax, results= annot.annotate()

annot.new_plot(ax, data=df, x="day", y="total_bill", order = ["Sun", "Thur", "Fri", "Sat"])
annot.configure(comparisons_correction="BH", correction_format="replace")
annot.apply_and_annotate()
# Out:
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Sun vs. Thur: Mann-Whitney-Wilcoxon test two-sided, P_val:5.363e-03 U_stat=3.007e+03
# Sun vs. Fri: Mann-Whitney-Wilcoxon test two-sided, P_val:2.680e-02 U_stat=9.605e+02
# Sun vs. Sat: Mann-Whitney-Wilcoxon test two-sided, P_val:3.585e-01 U_stat=3.582e+03
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Sun vs. Thur: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:5.363e-03 U_stat=3.007e+03
# Sun vs. Fri: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:2.680e-02 U_stat=9.605e+02
# Sun vs. Sat: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:3.585e-01 U_stat=3.582e+03
# (<AxesSubplot:xlabel='Day', ylabel='Total_bill'>,
#  [<statannotations.Annotation.Annotation at 0x7fd6281493d0>,
#   <statannotations.Annotation.Annotation at 0x7fd6212e6820>,
#   <statannotations.Annotation.Annotation at 0x7fd62130ed30>])
